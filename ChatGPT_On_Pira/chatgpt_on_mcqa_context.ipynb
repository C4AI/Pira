# %%
import openai
import pandas as pd
from tqdm import tqdm


# PARAMETERS
openai.api_key = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'

MODELS = ['gpt-3.5-turbo', 'gpt-4']

DATASET = 'test_sets/test_mcqa_context.csv'


def chatgpt_answer(prompt, model='gpt-3.5-turbo'):
    # Available models: 'gpt-3.5-turbo' and 'gpt-4'

    response = openai.ChatCompletion.create(
        model=model,
        temperature=0.0,
        max_tokens=100,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
        messages=[
            {'role': 'system', 
             'content': prompt}
        ]
    )
    
    return response.choices[0].message.content

# %%
df = pd.read_csv(DATASET)
print(len(df))
df.head()
# Out:
# 227
#       id                                               text  \
# 0  A1842  Geologic events related to the opening of the ...
# 1   A436  Parque das Conchas is an ultra-deepwater heavy...
# 2  A1329  The effects of the global climate change on oc...
# 3   A859  US subsea engineer Global Industries has recei...
# 4  A1950  Deep-sea fans have been proposed to act as car...
#
#                                             question  \
# 0  What geological phenomenon recorded the return...
# 1  Which companies are participating in the proje...
# 2  How are the effects of global climate change m...
# 3  Who will perform the installation of the camar...
# 4                         What does GHSZ stand for?
#
#                                                    A  \
# 0  By a lower level of black shales with fossil-r...
# 1  The project is a joint venture between Shell, ...
# 2  To guarantee the quality of coastal population...
# 3                              About 80 km offshore
# ...

# %%
for model in MODELS:
    print(f'\n\n>>> MODEL: {model}')

    gpt = []
    is_right = []
    for _, row in tqdm(df.iterrows()):
        ans = chatgpt_answer(row['prompt'], model)
        
        gpt.append(ans)
        is_right.append(1 if ans[0] == row['alternative'] else 0)

    df['gpt_selected_choice'] = gpt
    df['is_right'] = is_right

    df.to_csv(f'results/experiments_chatgpt_mcqa/{model}_context.csv', index=False)
# Out:
# >>> MODEL: gpt-3.5-turbo
# 227it [05:59,  1.59s/it]
# >>> MODEL: gpt-4
# 227it [07:22,  1.95s/it]

# %%
df
# Out:
#         id                                               text  \
# 0    A1842  Geologic events related to the opening of the ...
# 1     A436  Parque das Conchas is an ultra-deepwater heavy...
# 2    A1329  The effects of the global climate change on oc...
# 3     A859  US subsea engineer Global Industries has recei...
# 4    A1950  Deep-sea fans have been proposed to act as car...
# ..     ...                                                ...
# 222  A1819  The oil industry's search for new hydrocarbon ...
# 223  A1129  Terry Knott visited the newbuild Skandi Aker t...
# 224  A1830  Brazilian Environmental Authority (IBAMA) adop...
# 225  A1168  On July 16, 2000, a crude oil spill occurred a...
# 226   A874  Petrobras will invest at least $3.5 billion in...
#
#                                               question  \
# 0    What geological phenomenon recorded the return...
# 1    Which companies are participating in the proje...
# ...

# %%
df = pd.read_csv("results/experiments_chatgpt_mcqa/gpt-3.5-turbo_context.csv")
df.head()
# Out:
#       id                                               text  \
# 0  A1842  Geologic events related to the opening of the ...
# 1   A436  Parque das Conchas is an ultra-deepwater heavy...
# 2  A1329  The effects of the global climate change on oc...
# 3   A859  US subsea engineer Global Industries has recei...
# 4  A1950  Deep-sea fans have been proposed to act as car...
#
#                                             question  \
# 0  What geological phenomenon recorded the return...
# 1  Which companies are participating in the proje...
# 2  How are the effects of global climate change m...
# 3  Who will perform the installation of the camar...
# 4                         What does GHSZ stand for?
#
#                                                    A  \
# 0  By a lower level of black shales with fossil-r...
# 1  The project is a joint venture between Shell, ...
# 2  To guarantee the quality of coastal population...
# 3                              About 80 km offshore
# ...

# %%
df['is_right'].describe()
# Out:
# count    227.000000
# mean       0.947137
# std        0.224255
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: is_right, dtype: float64

# %%
df = pd.read_csv("results/experiments_chatgpt_mcqa/gpt-4_context.csv")
df.head()
# Out:
#       id                                               text  \
# 0  A1842  Geologic events related to the opening of the ...
# 1   A436  Parque das Conchas is an ultra-deepwater heavy...
# 2  A1329  The effects of the global climate change on oc...
# 3   A859  US subsea engineer Global Industries has recei...
# 4  A1950  Deep-sea fans have been proposed to act as car...
#
#                                             question  \
# 0  What geological phenomenon recorded the return...
# 1  Which companies are participating in the proje...
# 2  How are the effects of global climate change m...
# 3  Who will perform the installation of the camar...
# 4                         What does GHSZ stand for?
#
#                                                    A  \
# 0  By a lower level of black shales with fossil-r...
# 1  The project is a joint venture between Shell, ...
# 2  To guarantee the quality of coastal population...
# 3                              About 80 km offshore
# ...

# %%
df['is_right'].describe()
# Out:
# count    227.000000
# mean       0.951542
# std        0.215207
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: is_right, dtype: float64

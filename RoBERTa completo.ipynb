# %%
import pandas as pd
import datasets

# %%
## Parameters
language = 'english'
question_type = ['standard', 'human_paraphrase', 'automatic_paraphrase']
threshold = 3
dataset_types = ['soft', 'rigid', 'discrete']
model_type = 'roberta'

# %%
for questions in question_type:
    for classification_type in dataset_types:
        validation, test = pd.read_csv('validacao.csv'), pd.read_csv('teste.csv')

        if questions == 'standard':
            train = pd.read_csv('treinamento.csv')

            if language == 'english':
                train = train[['abstract', 'question_en_origin', 'answer_en_origin', 
                                            'question_meaningful', 'corpus', 'answer_in_text', 'answer_en_validate']]

                train.rename(columns={'question_en_origin': 'question', 'answer_en_origin': 'answer',
                                            'question_meaningful': 'label'}, inplace=True)

            if language == 'portuguese':
                train = train[['abstract', 'question_pt_origin', 'answer_pt_origin', 
                                            'question_meaningful', 'corpus', 'answer_in_text', 'answer_pt_validate']]

                train.rename(columns={'question_pt_origin': 'question', 'answer_pt_origin': 'answer',
                                            'question_meaningful': 'label'}, inplace=True)

        if questions == 'human_paraphrase':
            train = pd.read_csv('treinamento.csv')

            if language == 'english':

                # acrescentando paráfrases humanas
                trein_1 = train[['abstract', 'question_en_origin', 'answer_en_origin', 
                                        'question_meaningful', 'corpus' , 'answer_in_text']]
                trein_2 = train[['abstract', 'question_en_origin', 'answer_en_validate', 
                                        'question_meaningful', 'corpus', 'answer_in_text']]
                trein_3 = train[['abstract', 'question_en_paraphase', 'answer_en_origin', 
                                        'question_meaningful', 'corpus', 'answer_in_text']]
                trein_4 = train[['abstract', 'question_en_paraphase', 'answer_en_validate', 
                                        'question_meaningful', 'corpus', 'answer_in_text']]

                trein_1.columns = ['abstract', 'question', 'answer', 'label', 'corpus', 'answer_in_text']
                trein_2.columns = ['abstract', 'question', 'answer', 'label', 'corpus', 'answer_in_text']
                trein_3.columns = ['abstract', 'question', 'answer', 'label', 'corpus', 'answer_in_text']
                trein_4.columns = ['abstract', 'question', 'answer', 'label', 'corpus', 'answer_in_text']

                frames = [trein_1, trein_2, trein_3, trein_4]

                train = pd.concat(frames)

            if language == 'portuguese':

                # acrescentando paráfrases humanas
                trein_1 = train[['abstract', 'question_pt_origin', 'answer_pt_origin', 
                                        'question_meaningful', 'corpus', 'answer_in_text']]
                trein_2 = train[['abstract', 'question_pt_origin', 'answer_pt_validate', 
                                        'question_meaningful', 'corpus', 'answer_in_text']]
                trein_3 = train[['abstract', 'question_pt_paraphase', 'answer_pt_origin', 
                                        'question_meaningful', 'corpus', 'answer_in_text']]
                trein_4 = train[['abstract', 'question_pt_paraphase', 'answer_pt_validate', 
                                        'question_meaningful', 'corpus', 'answer_in_text']]

                trein_1.columns = ['abstract', 'question', 'answer', 'label', 'corpus', 'answer_in_text']
                trein_2.columns = ['abstract', 'question', 'answer', 'label', 'corpus', 'answer_in_text']
                trein_3.columns = ['abstract', 'question', 'answer', 'label', 'corpus', 'answer_in_text']
                trein_4.columns = ['abstract', 'question', 'answer', 'label', 'corpus', 'answer_in_text']

                frames = [trein_1, trein_2, trein_3, trein_4]

                train = pd.concat(frames)

        if questions == 'automatic_paraphrase':

            if language == 'english':
                df = pd.read_csv('parafrases_en_pegasus.csv')

                lst = []

                for i in range(1,7):
                    qu = 'question_' + str(i)
                    for j in range(1,7):
                        ans = 'answer_' + str(j)
                        data = df[['abstract', 'labels', qu, ans, 'corpus', 'answer_in_text']]
                        data = data.rename(columns={qu: 'question', ans: 'answer'})
                        lst.append(data)

                train = pd.concat(lst)

                train.rename(columns={'labels': 'label'}, inplace=True)
                validation.rename(columns={'labels': 'label'}, inplace=True)
                test.rename(columns={'labels': 'label'}, inplace=True)
                
            if language == 'portuguese':
                df = pd.read_csv('parafrases_pt.csv')

                lst = []

                for i in range(1,7):
                    qu = 'question_' + str(i)
                    for j in range(1,7):
                        ans = 'answer_' + str(j)
                        data = df[['abstract', 'labels', qu, ans, 'corpus', 'answer_in_text']]
                        data = data.rename(columns={qu: 'question', ans: 'answer'})
                        lst.append(data)

                train = pd.concat(lst)
                
                train.rename(columns={'labels': 'label'}, inplace=True)
                validation.rename(columns={'labels': 'label'}, inplace=True)
                test.rename(columns={'labels': 'label'}, inplace=True)


        if language == 'english':
            validation = validation[['corpus', 'abstract', 'question_en_origin', 'answer_en_origin', 
                                   'question_meaningful', 'answer_in_text', 'answer_en_validate']]
            test = test[['corpus', 'abstract', 'question_en_origin', 'answer_en_origin', 
                            'question_meaningful', 'answer_in_text', 'answer_en_validate']]
            validation.rename(columns={'question_en_origin': 'question', 'answer_en_origin': 'answer',
                                          'question_meaningful': 'label'}, inplace=True)
            test.rename(columns={'question_en_origin': 'question', 'answer_en_origin': 'answer',
                                      'question_meaningful': 'label'}, inplace=True)

        if language == 'portuguese':
            validation = validation[['corpus', 'abstract', 'question_pt_origin', 'answer_pt_origin', 
                                   'question_meaningful', 'answer_in_text', 'answer_pt_validate']]
            test = test[['corpus', 'abstract', 'question_pt_origin', 'answer_pt_origin', 
                            'question_meaningful', 'answer_in_text', 'answer_pt_validate']]
            validation.rename(columns={'question_pt_origin': 'question', 'answer_pt_origin': 'answer',
                                          'question_meaningful': 'label'}, inplace=True)
            test.rename(columns={'question_pt_origin': 'question', 'answer_pt_origin': 'answer',
                                      'question_meaningful': 'label'}, inplace=True)
        

        ## Cleaning the data

        # tirar as tags
        train = train.replace('<[^<]+?>', ' ', regex=True)
        validation = validation.replace('<[^<]+?>', ' ', regex=True)
        test = test.replace('<[^<]+?>', ' ', regex=True)

        # tirar quebra de linha, parágrafo
        train.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True, inplace=True)
        validation.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True, inplace=True)
        test.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True, inplace=True)

        # remove front and ending blank spaces
        train = train.replace({"^\s*|\s*$":""}, regex=True)
        validation = validation.replace({"^\s*|\s*$":""}, regex=True)
        test = test.replace({"^\s*|\s*$":""}, regex=True)

        # remove multiple whitespace
        train = train.replace('\s+', ' ', regex=True)
        validation = validation.replace('\s+', ' ', regex=True)
        test = test.replace('\s+', ' ', regex=True)

        #dropna
        train = train.dropna()
        validation = validation.dropna()
        test = test.dropna()

        ## Context
        train['text'] = train['abstract'] + " </s> " + train['question']
        validation['text'] = validation['abstract'] + " </s> " + validation['question']
        test['text'] = test['abstract'] + " </s> " + test['question']

        test['label'].value_counts()

        # create classfication labels

        if classification_type == 'rigid':
            train = train.loc[(train['label'] == 1) | (train['label'] == 5)]
            validation = validation.loc[(validation['label'] == 1) | (validation['label'] == 5)]
            test = test.loc[(test['label'] == 1) | (test['label'] == 5)]

        if classification_type == 'divided':
            train = train.loc[(train['label'] < threshold) | (train['label'] > threshold)]
            validation = validation.loc[(validation['label'] < threshold) | (validation['label'] > threshold)]
            test = test.loc[(test['label'] < threshold) | (test['label'] > threshold)]

        train['label'] = train['label'].apply(lambda x: 1 if x > threshold else 0)
        validation['label'] = validation['label'].apply(lambda x: 1 if x > threshold else 0)
        test['label'] = test['label'].apply(lambda x: 1 if x > threshold else 0)

        from datasets import Dataset

        train_dataset = Dataset.from_dict(train)
        validation_dataset = Dataset.from_dict(validation)
        test_dataset = Dataset.from_dict(test)

        my_dataset_dict = datasets.DatasetDict({"train":train_dataset, 
                                                'validation': validation_dataset, "test":test_dataset})

        my_dataset_dict

        ## Classification

        # options: distilbert, roberta, albert

        if model_type == 'bertimbau':
            model_name = 'neuralmind/bert-base-portuguese-cased'
        if model_type == 'distilbert':
            model_name = 'mvonwyl/distilbert-base-uncased-finetuned-squad2'
        if model_type == 'roberta':
            model_name = 'deepset/roberta-base-squad2'
        if model_type == 'albert':
            model_name = 'squirro/albert-base-v2-squad_v2'

        ### Tokenizer

        from transformers import AutoTokenizer

        tokenizer = AutoTokenizer.from_pretrained(model_name)

        def preprocess_function(examples):
            return tokenizer(examples["text"], truncation=True, padding=True, max_length=512)

        tokenized_text = my_dataset_dict.map(preprocess_function, batched=True)

        from transformers import DataCollatorWithPadding

        data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

        ### Train

        from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)

        model.num_parameters()

        training_args = TrainingArguments(
            output_dir="./results",
            learning_rate=2e-5,
            per_device_train_batch_size=16,
            per_device_eval_batch_size=16,
            num_train_epochs=8,
            weight_decay=0.01,
            save_total_limit = 1,
            overwrite_output_dir = 'True',
            load_best_model_at_end=True,
            save_strategy = "no",
            seed = 42
        )

        trainer = Trainer(
            model=model,
            args=training_args,
            train_dataset=tokenized_text["train"],
            eval_dataset=tokenized_text["validation"],
            tokenizer=tokenizer,
            data_collator=data_collator,
        )

        trainer.train()

        ## Prediction

        results = trainer.predict(tokenized_text['test']).predictions

        import numpy as np

        test['predictions'] = np.argmax(results, axis=-1)

        test['label'].value_counts()

        ## Metrics        
        from sklearn.metrics import f1_score, accuracy_score

        print('Test:', questions, classification_type)
        print('Accuracy:', accuracy_score(test['label'], test['predictions']))
        print('F1-score:', f1_score(test['label'], test['predictions'], average='macro'))
# Out:
# Parameter 'function'=<function preprocess_function at 0x7fb4947165e0> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Some weights of the model checkpoint at deepset/roberta-base-squad2 were not used when initializing RobertaForSequenceClassification: ['qa_outputs.weight', 'qa_outputs.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# The following columns in the training set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, answer_en_validate, abstract, corpus.
# ***** Running training *****
#   Num examples = 1755
#   Num Epochs = 8
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 440
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: paulopirozelli. Use `wandb login --relogin` to force relogin
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# wandb version 0.12.20 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.18
# Run data is saved locally in <code>/home/ppirozelli/Área de Trabalho/Classification/wandb/run-20220629_145711-227ors8v</code>
# Syncing run <strong><a href="https://wandb.ai/paulopirozelli/huggingface/runs/227ors8v" target="_blank">./results</a></strong> to <a href="https://wandb.ai/paulopirozelli/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# /home/ppirozelli/anaconda3/lib/python3.9/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='440' max='440' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [440/440 02:41, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, answer_en_validate, abstract, corpus.
# ***** Running Prediction *****
#   Num examples = 216
#   Batch size = 32
#     <div>
#
#       <progress value='7' max='7' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7/7 00:00]
#     </div>
# Test: standard soft
# Accuracy: 0.7268518518518519
# F1-score: 0.4518002322880372
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/vocab.json from cache at /home/ppirozelli/.cache/huggingface/transformers/81c80edb4c6cefa5cae64ccfdb34b3b309ecaf60da99da7cd1c17e24a5d36eb5.647b4548b6d9ea817e82e7a9231a320231a1c9ea24053cc9e758f3fe68216f05
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/merges.txt from cache at /home/ppirozelli/.cache/huggingface/transformers/b87d46371731376b11768b7839b1a5938a4f77d6bd2d9b683f167df0026af432.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/special_tokens_map.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c9d2c178fac8d40234baa1833a3b1903d393729bf93ea34da247c07db24900d0.cb2244924ab24d706b02fd7fcedaea4531566537687a539ebb94db511fd122a0
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/tokenizer_config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/e8a600814b69e3ee74bb4a7398cc6fef9812475010f16a6c9f151b2c2772b089.451739a2f3b82c3375da0dfc6af295bedc4567373b171f514dd09a4cc4b31513
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/pytorch_model.bin from cache at /home/ppirozelli/.cache/huggingface/transformers/eac3273a8097dda671e3bea1db32c616e74f36a306c65b4858171c98d6db83e9.084aa7284f3a51fa1c8f0641aa04c47d366fbd18711f29d0a995693cfdbc9c9e
# Some weights of the model checkpoint at deepset/roberta-base-squad2 were not used when initializing RobertaForSequenceClassification: ['qa_outputs.weight', 'qa_outputs.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# The following columns in the training set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, answer_en_validate, abstract, corpus.
# ***** Running training *****
#   Num examples = 1217
#   Num Epochs = 8
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 312
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# /home/ppirozelli/anaconda3/lib/python3.9/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='312' max='312' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [312/312 01:54, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, answer_en_validate, abstract, corpus.
# ***** Running Prediction *****
#   Num examples = 145
#   Batch size = 32
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:00]
#     </div>
# Test: standard rigid
# Accuracy: 0.9310344827586207
# F1-score: 0.48214285714285715
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/vocab.json from cache at /home/ppirozelli/.cache/huggingface/transformers/81c80edb4c6cefa5cae64ccfdb34b3b309ecaf60da99da7cd1c17e24a5d36eb5.647b4548b6d9ea817e82e7a9231a320231a1c9ea24053cc9e758f3fe68216f05
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/merges.txt from cache at /home/ppirozelli/.cache/huggingface/transformers/b87d46371731376b11768b7839b1a5938a4f77d6bd2d9b683f167df0026af432.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/special_tokens_map.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c9d2c178fac8d40234baa1833a3b1903d393729bf93ea34da247c07db24900d0.cb2244924ab24d706b02fd7fcedaea4531566537687a539ebb94db511fd122a0
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/tokenizer_config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/e8a600814b69e3ee74bb4a7398cc6fef9812475010f16a6c9f151b2c2772b089.451739a2f3b82c3375da0dfc6af295bedc4567373b171f514dd09a4cc4b31513
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/pytorch_model.bin from cache at /home/ppirozelli/.cache/huggingface/transformers/eac3273a8097dda671e3bea1db32c616e74f36a306c65b4858171c98d6db83e9.084aa7284f3a51fa1c8f0641aa04c47d366fbd18711f29d0a995693cfdbc9c9e
# Some weights of the model checkpoint at deepset/roberta-base-squad2 were not used when initializing RobertaForSequenceClassification: ['qa_outputs.weight', 'qa_outputs.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# The following columns in the training set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, answer_en_validate, abstract, corpus.
# ***** Running training *****
#   Num examples = 1755
#   Num Epochs = 8
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 440
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# /home/ppirozelli/anaconda3/lib/python3.9/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='440' max='440' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [440/440 02:46, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, answer_en_validate, abstract, corpus.
# ***** Running Prediction *****
#   Num examples = 216
#   Batch size = 32
#     <div>
#
#       <progress value='7' max='7' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7/7 00:00]
#     </div>
# Test: standard discrete
# Accuracy: 0.7916666666666666
# F1-score: 0.5161049434957933
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/vocab.json from cache at /home/ppirozelli/.cache/huggingface/transformers/81c80edb4c6cefa5cae64ccfdb34b3b309ecaf60da99da7cd1c17e24a5d36eb5.647b4548b6d9ea817e82e7a9231a320231a1c9ea24053cc9e758f3fe68216f05
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/merges.txt from cache at /home/ppirozelli/.cache/huggingface/transformers/b87d46371731376b11768b7839b1a5938a4f77d6bd2d9b683f167df0026af432.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/special_tokens_map.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c9d2c178fac8d40234baa1833a3b1903d393729bf93ea34da247c07db24900d0.cb2244924ab24d706b02fd7fcedaea4531566537687a539ebb94db511fd122a0
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/tokenizer_config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/e8a600814b69e3ee74bb4a7398cc6fef9812475010f16a6c9f151b2c2772b089.451739a2f3b82c3375da0dfc6af295bedc4567373b171f514dd09a4cc4b31513
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#   0%|          | 0/7 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/pytorch_model.bin from cache at /home/ppirozelli/.cache/huggingface/transformers/eac3273a8097dda671e3bea1db32c616e74f36a306c65b4858171c98d6db83e9.084aa7284f3a51fa1c8f0641aa04c47d366fbd18711f29d0a995693cfdbc9c9e
# Some weights of the model checkpoint at deepset/roberta-base-squad2 were not used when initializing RobertaForSequenceClassification: ['qa_outputs.weight', 'qa_outputs.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# The following columns in the training set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, abstract, corpus.
# ***** Running training *****
#   Num examples = 6676
#   Num Epochs = 8
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1672
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# /home/ppirozelli/anaconda3/lib/python3.9/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='1672' max='1672' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1672/1672 10:44, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.335600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.109200</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.065400</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, answer_en_validate, abstract, corpus.
# ***** Running Prediction *****
#   Num examples = 216
#   Batch size = 32
#     <div>
#
#       <progress value='7' max='7' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7/7 00:00]
#     </div>
# Test: human_paraphrase soft
# Accuracy: 0.7870370370370371
# F1-score: 0.497165991902834
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/vocab.json from cache at /home/ppirozelli/.cache/huggingface/transformers/81c80edb4c6cefa5cae64ccfdb34b3b309ecaf60da99da7cd1c17e24a5d36eb5.647b4548b6d9ea817e82e7a9231a320231a1c9ea24053cc9e758f3fe68216f05
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/merges.txt from cache at /home/ppirozelli/.cache/huggingface/transformers/b87d46371731376b11768b7839b1a5938a4f77d6bd2d9b683f167df0026af432.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/special_tokens_map.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c9d2c178fac8d40234baa1833a3b1903d393729bf93ea34da247c07db24900d0.cb2244924ab24d706b02fd7fcedaea4531566537687a539ebb94db511fd122a0
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/tokenizer_config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/e8a600814b69e3ee74bb4a7398cc6fef9812475010f16a6c9f151b2c2772b089.451739a2f3b82c3375da0dfc6af295bedc4567373b171f514dd09a4cc4b31513
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#   0%|          | 0/5 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/pytorch_model.bin from cache at /home/ppirozelli/.cache/huggingface/transformers/eac3273a8097dda671e3bea1db32c616e74f36a306c65b4858171c98d6db83e9.084aa7284f3a51fa1c8f0641aa04c47d366fbd18711f29d0a995693cfdbc9c9e
# Some weights of the model checkpoint at deepset/roberta-base-squad2 were not used when initializing RobertaForSequenceClassification: ['qa_outputs.weight', 'qa_outputs.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# The following columns in the training set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, abstract, corpus.
# ***** Running training *****
#   Num examples = 4638
#   Num Epochs = 8
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1160
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# /home/ppirozelli/anaconda3/lib/python3.9/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='1160' max='1160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1160/1160 07:27, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.108100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.026800</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, answer_en_validate, abstract, corpus.
# ***** Running Prediction *****
#   Num examples = 145
#   Batch size = 32
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:00]
#     </div>
# Test: human_paraphrase rigid
# Accuracy: 0.9379310344827586
# F1-score: 0.48398576512455516
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/vocab.json from cache at /home/ppirozelli/.cache/huggingface/transformers/81c80edb4c6cefa5cae64ccfdb34b3b309ecaf60da99da7cd1c17e24a5d36eb5.647b4548b6d9ea817e82e7a9231a320231a1c9ea24053cc9e758f3fe68216f05
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/merges.txt from cache at /home/ppirozelli/.cache/huggingface/transformers/b87d46371731376b11768b7839b1a5938a4f77d6bd2d9b683f167df0026af432.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/special_tokens_map.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c9d2c178fac8d40234baa1833a3b1903d393729bf93ea34da247c07db24900d0.cb2244924ab24d706b02fd7fcedaea4531566537687a539ebb94db511fd122a0
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/tokenizer_config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/e8a600814b69e3ee74bb4a7398cc6fef9812475010f16a6c9f151b2c2772b089.451739a2f3b82c3375da0dfc6af295bedc4567373b171f514dd09a4cc4b31513
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#   0%|          | 0/7 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# ...
# Some weights of the model checkpoint at deepset/roberta-base-squad2 were not used when initializing RobertaForSequenceClassification: ['qa_outputs.weight', 'qa_outputs.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# The following columns in the training set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, abstract, corpus.
# ***** Running training *****
#   Num examples = 43812
#   Num Epochs = 8
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 10960
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# /home/ppirozelli/anaconda3/lib/python3.9/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='10960' max='10960' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10960/10960 1:10:42, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.100400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.030600</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.022000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.013600</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.015500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.014900</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.013800</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.009700</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.010400</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.012400</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.011200</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.012500</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.011100</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.011600</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.010000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.009600</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.010700</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.009700</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.011000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.010300</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.009700</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, answer_en_validate, abstract, corpus.
# ***** Running Prediction *****
#   Num examples = 145
#   Batch size = 32
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:00]
#     </div>
# Test: automatic_paraphrase rigid
# Accuracy: 0.9172413793103448
# F1-score: 0.4784172661870504
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/vocab.json from cache at /home/ppirozelli/.cache/huggingface/transformers/81c80edb4c6cefa5cae64ccfdb34b3b309ecaf60da99da7cd1c17e24a5d36eb5.647b4548b6d9ea817e82e7a9231a320231a1c9ea24053cc9e758f3fe68216f05
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/merges.txt from cache at /home/ppirozelli/.cache/huggingface/transformers/b87d46371731376b11768b7839b1a5938a4f77d6bd2d9b683f167df0026af432.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/special_tokens_map.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c9d2c178fac8d40234baa1833a3b1903d393729bf93ea34da247c07db24900d0.cb2244924ab24d706b02fd7fcedaea4531566537687a539ebb94db511fd122a0
# loading file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/tokenizer_config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/e8a600814b69e3ee74bb4a7398cc6fef9812475010f16a6c9f151b2c2772b089.451739a2f3b82c3375da0dfc6af295bedc4567373b171f514dd09a4cc4b31513
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#   0%|          | 0/64 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# loading configuration file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/config.json from cache at /home/ppirozelli/.cache/huggingface/transformers/c40d0abb589629c48763f271020d0b1f602f5208c432c0874d420491ed37e28b.122ed338b3591c07dba452777c59ff52330edb340d3d56d67aa9117ad9905673
# Model config RobertaConfig {
#   "_name_or_path": "deepset/roberta-base-squad2",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "language": "english",
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "name": "Roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.14.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file https://huggingface.co/deepset/roberta-base-squad2/resolve/main/pytorch_model.bin from cache at /home/ppirozelli/.cache/huggingface/transformers/eac3273a8097dda671e3bea1db32c616e74f36a306c65b4858171c98d6db83e9.084aa7284f3a51fa1c8f0641aa04c47d366fbd18711f29d0a995693cfdbc9c9e
# Some weights of the model checkpoint at deepset/roberta-base-squad2 were not used when initializing RobertaForSequenceClassification: ['qa_outputs.weight', 'qa_outputs.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# The following columns in the training set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, abstract, corpus.
# ***** Running training *****
#   Num examples = 63180
#   Num Epochs = 8
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 15800
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# /home/ppirozelli/anaconda3/lib/python3.9/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='15800' max='15800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [15800/15800 1:41:40, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.410200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.202000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.128800</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.105600</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.078500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.060500</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.067400</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.053400</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.051400</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.046600</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.046800</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.046100</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.046400</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.049900</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.041800</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.047600</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.043700</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.047600</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.042700</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.039300</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.036800</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.036500</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.036500</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.040000</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.037800</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.035400</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.035800</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.035500</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.036100</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.033300</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.035100</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: answer_in_text, answer, text, question, answer_en_validate, abstract, corpus.
# ***** Running Prediction *****
#   Num examples = 216
#   Batch size = 32
#     <div>
#
#       <progress value='7' max='7' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7/7 00:00]
#     </div>
# Test: automatic_paraphrase discrete
# Accuracy: 0.7777777777777778
# F1-score: 0.507598784194529
